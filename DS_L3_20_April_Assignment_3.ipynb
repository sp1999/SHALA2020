# %% [markdown]
# <a href="https://colab.research.google.com/github/sp1999/SHALA2020/blob/master/DS_L3_20_April_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment - 3: Improving Graphs**
#
# ---
# Course website: [SHALA-2020](https://shala2020.github.io/)
#
# This assignment will get you familiarized with improving plots/graphs in Python.

# %% [markdown]
# ---
# ## Part 1 - Importing packages and loading data
# ---

# %% [markdown]
# ###Import the following libraries:
#
# * ```numpy``` with an alias name ```np```,
# * ```pandas``` with an alias name ```pd```,
# * ```matplotlib.pyplot``` with an alias name ```plt```, and
# * ```seaborn``` with an alias name ```sns```.
#
# *You are free to use any other popular libraries*.

# %%
# Load the libraries with their aliases 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Using the files ```train.csv``` and ```moviesData.csv```,  peform the following:
#
# * Load these file as ```pandas``` dataframes and store it in variables named ```train``` and ```movies``` respectively.
# * Print the first ten rows of ```train``` and last ten rows of ```movies```.

# %%
# Load train.csv and movies.csv 
url_train = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Assignments/DataScience/L2/train.csv"
train = pd.read_csv(url_train)

# Print the first ten rows of train
train.head(10)
# Out:
#    Age  Attrition  ... YearsWithCurrManager  ID
# 0   41          1  ...                    5   0
# 1   49          0  ...                    7   1
# 2   37          1  ...                    0   2
# 3   33          0  ...                    0   3
# 4   27          0  ...                    2   4
# 5   32          0  ...                    6   5
# 6   59          0  ...                    0   6
# 7   30          0  ...                    0   7
# 8   38          0  ...                    8   8
# 9   36          0  ...                    7   9
#
# [10 rows x 34 columns]

# %%
# Load movies.csv
url_movies = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Google_Colab_Notebooks/DataScience/L2/moviesData.csv"
movies = pd.read_csv(url_movies)

# Print the last ten rows of movies 
movies.tail(10)
# Out:
#      Unnamed: 0  ...            actor5
# 590         591  ...        Ben Vereen
# 591         592  ...       Bob Balaban
# 592         593  ...     George Gaynes
# 593         594  ...   Lance Henriksen
# 594         595  ...  Steve Guttenberg
# 595         596  ...       Jack Bailey
# 596         597  ...       Rachel True
# 597         598  ...    Randy McDowell
# 598         599  ...       Ian McNeice
# 599         600  ...    Adam G. Sevani
#
# [10 rows x 31 columns]

# %% [markdown]
# ---
# ## Part 2 - Drawing correlation and heatmap
# ---

# %% [markdown]
# ### Using the correlation matrix, peform the following:
#
# * Find the correlation matrix for the ```movies```.
# * Draw a **heatmap** with the correlation matrix and display the values of correlation coefficients for each pair of features. Make sure the values are properly visible. You might want to adjust the figure size for this.
# * Create a ```mask``` to remove the duplicate values from the **heatmap**.

# %%
# Find out the correlation matrix 
corr_Matrix = movies.corr()
# Draw the heatmap 
plt.figure(figsize=(20,10))
sns.heatmap(corr_Matrix, vmin = -1, vmax = 1, center = 0, annot = True)

# %%
# Creating a mask for removing duplicates 
mask = np.zeros(corr_Matrix.shape, dtype=bool)
mask[np.triu_indices(len(mask))] = True
plt.figure(figsize=(20,10))
sns.heatmap(corr_Matrix, vmin = -1, vmax = 1, center = 0, annot = True, cmap = "coolwarm", mask = mask)

# %% [markdown]
# ---
# ## Part 3 - Drawing plots and customizing these
# ---

# %% [markdown]
# ### Using a histogram, peform the following:
#
# * Draw a histogram of all the numeric features in ```train```. Please note that this can be done in a single command.
#
# * Find out whether there is any redundant features in ```train```, which can be dropped while building a model.

# %%
# Draw a histogram 
train.hist(figsize=(20,20))
# Find out the redundant features
# Clearly we can see that "ID", "Daily Rate", "Monthly Rate", "Employee Number" and "Hourly Rate" are redundant features as they have almost uniform distribution
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f03c9b6bc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c947a470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c942d6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c93dea58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c9393dd8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f03c93d2198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03cab0eeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03ca7425f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03ca742e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03ca2559b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f03c9518e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c93779e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c926ec50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c9221eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c91e2160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f03c91963c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c91ca630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c917d898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c912fb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c90e6d68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f03c9099fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c9058278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c908e4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c9041748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c8ff59b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f03c8fa9c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c8f5ee80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c8f1f128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c8f51390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f03c8f085f8>]],
#       dtype=object)

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Draw a scatter plot between between ```imdb_rating``` and ```audience_score```, and also fit a regression line.
# * Change the color of marker to red, size to 200, transparency to 0.3.

# %%
# Scatter plot to fit the regression line 
plt.figure(figsize=(20,10))
plt.style.use('ggplot')
sns.regplot(movies["imdb_rating"], movies["audience_score"], scatter_kws={"color":"red","alpha":0.3,"s":200})
plt.title("scatter plot of imdb_rating vs audience_score")
plt.xlabel("imdb_rating")
plt.ylabel("audience_score")
plt.show()

# %%
# Change marker of the scatter plot
plt.figure(figsize=(20,10))
plt.style.use('ggplot')
plt.scatter(movies["imdb_rating"], movies["audience_score"], c="blue", marker="x")
m, b = np.polyfit(movies["imdb_rating"], movies["audience_score"], 1)
plt.plot(movies["imdb_rating"], m*movies["imdb_rating"] + b)
plt.title("scatter plot of imdb_rating vs audience_score")
plt.xlabel("imdb_rating")
plt.ylabel("audience_score")
plt.show()

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw a scatter plot between between ```petal_length``` and ```petal_width``` and color it according to the ```species```.
# * Change the size of marker to 100 and place the legend in ```lower right```.

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')
 
# Use the 'hue' argument to provide a factor variable
plt.figure(figsize=(20,10))
plt.style.use('ggplot')
sns.lmplot(x="petal_length", y="petal_width", data=df, hue="species", fit_reg=False, scatter_kws={"s":100}, legend=False)

# Move the legend to an empty part of the plot
plt.legend(loc='lower right')

# %% [markdown]
# ---
# ## Part 4 - Density Plots
# ---

# %% [markdown]
# ### Using density plots, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots for all the features ```sepal_width```, ```sepal_length```, ```petal_width```, and ```petal_length```. You can required to use subplots for plotting all the density plots.
# * Try drawing a [CDF](https://en.wikipedia.org/wiki/Cumulative_distribution_function) of these features. There is a [blog on medium](https://medium.com/@rishav.jnit/exploratory-data-analysis-eda-on-iris-dataset-using-python-cadd850c1fc6) on how to plot CDF. It will be covered in tutorial.

# %%
# library and dataset 
df = sns.load_dataset('iris')
plt.figure(figsize=(20,10))
plt.style.use('ggplot')

plt.subplot(2,2,1)
sns.kdeplot(df['sepal_width'], color="yellow", shade=True)

plt.subplot(2,2,2)
sns.kdeplot(df['sepal_length'], color="red", shade=True)

plt.subplot(2,2,3)
sns.kdeplot(df['petal_width'], color="blue", shade=True)

plt.subplot(2,2,4)
sns.kdeplot(df['petal_length'], color="green", shade=True)

# %%
plt.figure(figsize=(20,10))
plt.style.use('ggplot')

plt.subplot(2,2,1)
sns.kdeplot(df['sepal_width'], color="yellow", shade=True, cumulative=True)

plt.subplot(2,2,2)
sns.kdeplot(df['sepal_length'], color="red", shade=True, cumulative=True)

plt.subplot(2,2,3)
sns.kdeplot(df['petal_width'], color="blue", shade=True, cumulative=True)

plt.subplot(2,2,4)
sns.kdeplot(df['petal_length'], color="green", shade=True, cumulative=True)

# %% [markdown]
# ### Using violin plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots of ```species``` versus ```sepal_length```.
# * Assign each group a color like
#
#     * versicolor - green,
#     * setosa - blue,
#     * virginica - m

# %%
# Draw the normal violin plots 
sns.violinplot( x=df["species"], y=df["sepal_length"], palette={"setosa":"Blue", "versicolor":"green", "virginica":"red"})

# %%
# Change the color of each group 
sns.violinplot( x=df["species"], y=df["sepal_length"], palette={"setosa":"pink", "versicolor":"yellow", "virginica":"orange"})
